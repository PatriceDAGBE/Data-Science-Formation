# %%
# YouTube_Data_Scraping_Preprocessing_and_Analysis_using_Python
import time
from selenium import webdriver
from bs4 import BeautifulSoup
import xlsxwriter
import pandas as pd

# %%
urls = [
    'https://www.youtube.com/c/GeeksforGeeksVideos/videos'
]
driver = webdriver.Chrome()
soup = None

# %%
for url in urls:
    times = 0
    driver.get('{}/videos?view=0&sort=p&flow=grid'.format(url))
    while times < 5:
        time.sleep(1)   
        driver.execute_script(
            "window.scrollTo(0, document.documentElement.scrollHeight);")
        times += 1
    content = driver.page_source.encode('utf-8').strip()
    soup = BeautifulSoup(content, 'lxml')
print("Channel Scraping Done!")
# Out:
# Channel Scraping Done!

# %%
#Title
titles_all = soup.find_all(id='video-title')
titles = []
for title in titles_all:
    titles.append(title.text)
print(len(titles))
# Out:
# 74

# %%
#Views
views = []

#Durations
durations = []

videos = soup.select("ytd-rich-item-renderer")

spans = soup.select('#details #metadata-line span')
for i, span in enumerate(spans):
    if i % 2 == 0:
        views.append(spans[i].get_text(strip=True))

for video in videos:
    badge = video.find("badge-shape")
    if badge:
        dur = badge.find("div", class_="badge-shape-wiz__text")
        if dur:
            durations.append(dur.get_text(strip=True))

# %%
# Excel file creating

workbook = xlsxwriter.Workbook('file.xlsx')
worksheet = workbook.add_worksheet()

worksheet.write(0, 0, "Title")
worksheet.write(0, 1, "Views")
worksheet.write(0, 2, "Duration")

row = 1
for title, view, dura in zip(titles,views,durations):
    worksheet.write(row, 0, title)
    worksheet.write(row, 1, view)
    worksheet.write(row, 2, dura)
    row += 1

workbook.close()

# %%
data = pd.read_excel('file.xlsx')
data.head()
# Out:
#                                                Title       Views Duration
# 0  DSA In Java | If Else | Java in One Shot | If ...   311 views  2:43:11
# 1  DSA In Java | Basics | Java in One Shot | Outp...   11K views  4:18:01
# 2  What Is Data Science? | Data Science Roadmap |...  1.2K views    38:30
# 3  What Is Generative AI | 3 gen AI Project to bu...  2.2K views     5:16
# 4  BTech 1st Year Complete Roadmap 2025 🔥CSE/Non ...   40K views    11:10

# %%
# Views column cleaning
data['Views'] = data['Views'].str.replace(" views","")

new = []

for i in data['Views']:
    if(i.endswith('K')):
        i = i.replace('K','')
        new.append(float(i) * 1000)
    else :
        new.append(i)

data['Views'] = new

# %%
#Duration column cleaning
data['Duration'] = data['Duration'].str.replace("\n","")

new2 = []

for i in data['Duration']:
    if(i=='SHORTS' or len(i.split(':'))==1):
        new2.append(i)
    elif(len(i.split(':'))==2):
        i = i.split(':')
        tim = int(i[0])*60 + int(i[1])
        new2.append(tim)
    elif(len(i.split(':'))==3):
        i = i.split(':')
        tim = int(i[0])*3600 + int(i[1])*60 + int(i[2])
        new2.append(tim)
        
data['Duration'] = new2

# %%
#Duration column categorization
for i in data['Duration'].index:
    val = data['Duration'].iloc[i]
    if(val=='  SHORTS'):
        continue
    elif(val in range(0,900)):
        data.loc[i,'Duration'] = 'Mini-Videos'
    elif(val in range(901,3600)):
        data.loc[i,'Duration'] = 'Long-Videos'
    else:
        data.loc[i,'Duration'] = 'Very-Long-Videos'
data.head()
# Out:
#                                                Title    Views  \
# 0  dsa in java if else java one shot if else java...      311
# 1  dsa in java basics java one shot output input ...  11000.0
# 2  what is data science data science roadmap data...   1200.0
# 3  what is generative ai 3 gen ai project build s...   2200.0
# 4  btech 1st year complete roadmap 2025 csenon cs...  40000.0
#
#            Duration
# 0  Very-Long-Videos
# 1  Very-Long-Videos
# 2       Long-Videos
# 3       Mini-Videos
# 4       Mini-Videos

# %%
from tqdm import tqdm
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords

def preprocess_text(text_data):
    preprocessed_text = []
    
    for sentence in tqdm(text_data):
        sentence = re.sub(r'[^\w\s]', '', sentence)
        preprocessed_text.append(' '.join(token.lower()
                                    for token in str(sentence).split()
                                        if token not in stopwords.words('english')))

    return preprocessed_text

print(data["Title"].values)
preprocessed_review = preprocess_text(data['Title'].values)
data['Title'] = preprocessed_review
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/patricedagbe/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/patricedagbe/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['dsa in java if else java one shot if else java java course'
#  'dsa in java basics java one shot output input variables operators java course'
#  'what is data science data science roadmap data science step by step complete information'
#  'what is generative ai 3 gen ai project build stand resume'
#  'btech 1st year complete roadmap 2025 csenon cse branches what to do in college 1st year'
#  'nation skillup faq faq all answered utilize nation skillup learn win rewards'
#  'nimcet 2026 how to prepare nimcet 2026 big update for nimcet 2026 batch'
#  'nimcet roadmap nimcet 2026 preparation nimcet exam nimcet 2026 strategy'
#  'ai engineer roadmap how learn ai 2025 ai engineer'
#  'how score 9 cgpa college complete roadmap 2025 csenon cse branches internshipplacements'
#  'course walkthrough how utilize free courses nation skillup geeksforgeeks'
#  'bca 3rd year complete roadmap 2025 bca preparation bca roadmap'
#  'nation skillup geeksforgeeks 15 tech courses free'
#  'build ats friendly resume that gets shortlisted'
#  'if ambitious lazy please watch'
#  'hackwithinfy complete roadmap how crack get up 12 lpa salary'
#  'government jobs vs private jobs tech which better you'
#  'backend development roadmap 2025 become jobready'
#  'indias biggest launch gate ece ee aspirants complete roadmap 2026'
#  'all about nimcet how to do mca from top nits exam pattern syllabus cutoff resources'
#  'what to do in college 3rd year btech 3rd year complete roadmap'
#  'want crack system design interview use this 4step framework'
#  'javascript explained 7 minutes'
#  'nation skill up geeksforgeeks skillupwithgfg'
#  'how to start coding in 2025 2026 complete roadmap for beginners'
#  'how never fail technical interview' 'get ready skillupwithgfg'
#  'crack gate 2026 this strategy deep prep smart revision gfg tools'
#  'dsa free course dynamic programming in one shot dsa dp in one shot'
#  'i investigated tech layoffs 2025'
#  'the harsh truth about offcampus placements'
#  'how to become scientist in isro exam pattern cutoff syllabus stepbystep guide'
#  'most asked dsa questions interviews crack any coding round'
#  'the future coding here'
#  'btech vs bca which is better become software engineer'
#  'all about gate exam exam pattern syllabus eligibility complete information'
#  '10 programming myths you should know 2025'
#  'geeksforgeeks connect join us mentor tech expert'
#  'tech placement and internship preparation cohort tayyari batch qna'
#  'the harsh reality oncampus placements india'
#  'dsa roadmap beginner advanced level dsa 2025 preparation'
#  'government jobs after btech cse top opportunities cs students gfg_gate'
#  'gate vs offcampus placement which one should you choose'
#  'get internship 1st year college roadmap geeksforgeeks'
#  'dark side linkedin job hunting how actually get job 2025'
#  'how to learn dsa in 2025 dsa placement preparation dsa roadmap'
#  'what should you do btech 2nd year complete roadmap students btech roadmap'
#  'it jobs are dying watch before its too late the truth about it jobs 2025'
#  'gate discrete mathematics demo video satish sir what graph theory free gate course video'
#  'big update full dsa course java absolutely free dsa java'
#  'top 7 highpaying tech jobs 2025'
#  'model context protocol clearly explained just 15 minutes'
#  '160 days dsa now certified summer workshops register free'
#  'reality will ai take your jobhint it unless'
#  'can ai understand indian comedy understand sentiment analysis 8 minutes'
#  'oop 6 minutes real examples'
#  'how to make a resume for freshers make online free resume geeksforgeeks'
#  'firebase studio here googles gamechanging tool for developers'
#  'what nodejs work interview question part 2'
#  'what is vibe coding will it kill software engineering'
#  'gfg 160 daily dsa challenge daily problem solving'
#  'how to crack campus placementsinternships top tips 20 minutes geeksforgeeks'
#  'i went house zomato software engineer roadmap salary hiring insights perks etc'
#  'three 90 challenge ending 31st march'
#  'gsoc 2025 everything you need know' 'why cant gen z get job'
#  'prompts 10x your coding journey' 'binary trees explained 4 minutes'
#  'dynamic programming explained 6 minutes'
#  'i went iit delhi meet gate air 20 crack gate geeksforgeeks'
#  'struggling gate we help boost rank'
#  'what software engineers really do are software engineering jobs really'
#  'get 55 marks easily gate cs 2026 using strategy'
#  'a day life iit struggles successes meet apoorva gate air 20']
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [00:00<00:00, 1061.05it/s]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

# %%
consolidated = ' '.join(word for word in data['Title'].astype(str))
wordCloud = WordCloud(width=1600, height=800, random_state=21,
                      max_font_size=110, collocations=False)
plt.figure(figsize=(15, 10))
plt.imshow(wordCloud.generate(consolidated), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
sns.countplot(x="Duration", data=data)
plt.show()
